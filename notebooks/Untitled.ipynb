# %%
import pandas as pd
import torch
import numpy as np

# 1. 加载行业分类数据
# 路径关系：假设你在 notebooks/ 目录下，需要回退一级到根目录再进入 data
industry_df = pd.read_csv('../STK_INDUSTRYCLASS.csv', encoding='utf-8') 

# 2. 筛选证监会2012版标准 (P0207) 并获取最新的行业分类
industry_df = industry_df[industry_df['IndustryClassificationID'] == 'P0207']
industry_df = industry_df.sort_values('ImplementDate').drop_duplicates('Symbol', keep='last')

# 创建映射字典
industry_dict = dict(zip(industry_df['Symbol'].astype(str).str.zfill(6), industry_df['IndustryCode']))

# 3. 加载你处理好的 Stkcd 列表 (假设你在数据预处理阶段保存了 stkcds)
# 如果没有单独保存，通常与 node_features_X.pt 的第一维顺序一致
# 这里我们需要获取你模型输入中的 Symbol 顺序
# 示例：stkcds = torch.load('../data/processed/stkcds.pt') 
# 如果没有该文件，请回溯 build_dynamic_tensors.ipynb 中 unique_companies 的顺序

# 构造行业掩码
c38_mask = np.array([industry_dict.get(str(s), '') == 'C38' for s in stkcds])
c39_mask = np.array([industry_dict.get(str(s), '') == 'C39' for s in stkcds])

print(f"C38 企业数量: {c38_mask.sum()}")
print(f"C39 企业数量: {c39_mask.sum()}")
# Out:
# -------------------------------------------------------
# FileNotFoundError     Traceback (most recent call last)
# Cell In[1], line 7
#       3 import numpy as np
#       5 # 1. 加载行业分类数据
#       6 # 路径关系：假设你在 notebooks/ 目录下，需要回退一级到根目录再进入 data
# ----> 7 industry_df = pd.read_csv('../STK_INDUSTRYCLASS.csv', encoding='utf-8')
#       9 # 2. 筛选证监会2012版标准 (P0207) 并获取最新的行业分类
#      10 industry_df = industry_df[industry_df['IndustryClassificationID'] == 'P0207']
#
# ...
